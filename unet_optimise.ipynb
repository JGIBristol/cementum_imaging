# %%
import os

# %load_ext autoreload
# %autoreload 2

img_dir = "img/test_gpu_unet/"
if not os.path.exists(img_dir):
    os.makedirs(img_dir)

# %%
"""
Check if we have a GPU

"""
import tensorflow as tf
tf.config.list_physical_devices()
# Out:
# 2024-03-04 11:32:33.085763: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-04 11:32:33.085787: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-04 11:32:33.086247: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-04 11:32:33.089455: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-04 11:32:34.932537: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-04 11:32:34.951175: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-04 11:32:34.951348: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
"""
Open and resize the images for training

"""

import pathlib
import warnings
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from cementum import processing, util

# We don't have the same number of images and masks, unfortunately
# So we'll just open this many
train_fraction = 0.8
n_imgs = 516
n_total = 516

# Choose some images and masks at random
gen = np.random.default_rng(0)
indices = gen.choice(np.arange(n_total), size=n_imgs, replace=False)

# Split into training and testing here
train_indices = gen.choice(indices, size=int(train_fraction * n_imgs), replace=False)
test_indices = np.array([i for i in indices if i not in train_indices])

data_dir = pathlib.Path("data/original cut/")
mask_dir = pathlib.Path("data/masks cut/")

img_paths = np.array(sorted(tuple(data_dir.glob(r"????.tif"))))
mask_paths = np.array(sorted(tuple(pathlib.Path(mask_dir).glob(r"????.tif"))))

img_size = (320, 320)
train_images = np.array(
    [
        processing.resize(Image.open(str(path)), img_size)
        for path in img_paths[train_indices]
    ]
)
test_images = np.array(
    [
        processing.resize(Image.open(str(path)), img_size)
        for path in img_paths[test_indices]
    ]
)

# Subtract 1 from masks to make them 0-indexed
train_masks = np.array(
    [
        processing.resize(Image.open(str(path)), img_size) - 1
        for path in mask_paths[train_indices]
    ]
)
test_masks = np.array(
    [
        processing.resize(Image.open(str(path)), img_size) - 1
        for path in mask_paths[test_indices]
    ]
)

# Check that the masks all contain the right values - and contain all of them (which might be unnecessary)
for i, mask in enumerate(train_masks):
    assert (
        np.unique(mask) == [0, 1, 2]
    ).all(), f"{util.bcolours.FAIL}Mask {i} contains vals {util.bcolours.WARNING}{np.unique(mask)}"

assert len(train_images) == len(train_masks), len(train_images)
if len(train_images) + len(test_images) != n_imgs:
    warnings.warn(
        f"{util.bcolours.WARNING}Only {len(train_images) + len(test_images)} images were loaded"
    )

len(train_images), len(test_images), len(train_masks), len(test_masks)
# Out:
# (412, 104, 412, 104)

# %%
"""
Display some of them 

"""

rng = np.random.default_rng(seed=0)

indices = rng.choice(len(train_images), size=16, replace=False)

fig, axes = plt.subplots(4, 4, figsize=(10, 10))

for i, ax in zip(indices, axes.flat):
    ax.imshow(train_images[i], cmap="gray")
    ax.imshow(train_masks[i], cmap="viridis", alpha=0.5)
    ax.set_xticks([])
    ax.set_yticks([])

fig.suptitle("Training images and masks")

fig.tight_layout()

fig.savefig(f"{img_dir}training_images_and_masks.png")

# %%
"""
Find class weights

"""

from sklearn.utils.class_weight import compute_class_weight

classes = np.unique(train_masks)
class_weights = compute_class_weight(
    class_weight="balanced", classes=classes, y=train_masks.ravel()
)

# Increase cementum weight
class_weights[1] *= 8

class_weights = dict(enumerate(class_weights, start=0))

class_weights
# Out:
# {0: 0.9136543692956969, 1: 13.338325467718176, 2: 0.7658617029719764}

# %%
"""
Convert to arrays for training

"""
X_train = processing.imgs2array(train_images)
y_train = processing.masks2matrix(train_masks, len(classes))

X_train.shape, y_train.shape
# Out:
# ((412, 320, 320, 1), (412, 320, 320, 3))

# %%
"""
Train uNet on these images; recording the loss

"""

from keras.optimizers import Adam
from keras.metrics import Precision, Recall
from cementum import unet


def new_model(*, dropout: float, learning_rate: float):
    model = unet.my_unet(
        n_classes=3,
        IMG_HEIGHT=train_images[0].shape[0],
        IMG_WIDTH=train_images[0].shape[1],
        IMG_CHANNELS=1,
        dropout=dropout,
    )

    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss="categorical_crossentropy",
        metrics=["accuracy", Precision(), Recall()],
    )

    return model


model_params = {"dropout": 0.0, "learning_rate": 0.0002}
model = new_model(**model_params)
# Out:
# 2024-03-04 11:32:41.541109: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-04 11:32:41.541296: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-04 11:32:41.541410: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-04 11:32:41.675791: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-04 11:32:41.676068: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-04 11:32:41.676306: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-04 11:32:41.676458: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8245 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:51:00.0, compute capability: 8.6

# %%
train_kw = {
    "class_weight": class_weights,
    "batch_size": 16,
    "epochs": 60,
    "validation_split": 0.2,
    "verbose": 1,
}

# %%
history = model.fit(X_train, y_train, **train_kw)
# Out:
# Epoch 1/60
# 2024-03-04 11:32:44.097100: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8800
# 2024-03-04 11:32:45.799427: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f83e19b2140 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-03-04 11:32:45.799444: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2024-03-04 11:32:45.802408: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709551965.861394 1807911 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 21/21 [==============================] - 18s 352ms/step - loss: 2.1983 - accuracy: 0.1966 - precision: 0.2662 - recall: 0.1567 - val_loss: 1.4775 - val_accuracy: 0.2076 - val_precision: 0.2900 - val_recall: 0.2049
# Epoch 2/60
# 21/21 [==============================] - 2s 87ms/step - loss: 1.2303 - accuracy: 0.3572 - precision: 0.5212 - recall: 0.3549 - val_loss: 1.1683 - val_accuracy: 0.3372 - val_precision: 0.4931 - val_recall: 0.3363
# Epoch 3/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.8956 - accuracy: 0.5175 - precision: 0.7379 - recall: 0.4895 - val_loss: 0.7311 - val_accuracy: 0.6730 - val_precision: 0.7984 - val_recall: 0.5309
# Epoch 4/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.6716 - accuracy: 0.8197 - precision: 0.8591 - recall: 0.5662 - val_loss: 0.5343 - val_accuracy: 0.9041 - val_precision: 0.8980 - val_recall: 0.5991
# Epoch 5/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5403 - accuracy: 0.9088 - precision: 0.8908 - recall: 0.6029 - val_loss: 0.4251 - val_accuracy: 0.9282 - val_precision: 0.9163 - val_recall: 0.7338
# Epoch 6/60
# 21/21 [==============================] - 2s 84ms/step - loss: 0.3387 - accuracy: 0.9262 - precision: 0.9278 - recall: 0.8814 - val_loss: 0.1931 - val_accuracy: 0.9355 - val_precision: 0.9392 - val_recall: 0.9322
# Epoch 7/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.2177 - accuracy: 0.9357 - precision: 0.9402 - recall: 0.9317 - val_loss: 0.2105 - val_accuracy: 0.9304 - val_precision: 0.9341 - val_recall: 0.9267
# Epoch 8/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.1881 - accuracy: 0.9423 - precision: 0.9470 - recall: 0.9375 - val_loss: 0.1621 - val_accuracy: 0.9430 - val_precision: 0.9474 - val_recall: 0.9384
# Epoch 9/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.1708 - accuracy: 0.9472 - precision: 0.9514 - recall: 0.9433 - val_loss: 0.1719 - val_accuracy: 0.9352 - val_precision: 0.9402 - val_recall: 0.9311
# Epoch 10/60
# 21/21 [==============================] - 2s 84ms/step - loss: 0.1629 - accuracy: 0.9490 - precision: 0.9531 - recall: 0.9452 - val_loss: 0.1257 - val_accuracy: 0.9566 - val_precision: 0.9586 - val_recall: 0.9550
# Epoch 11/60
# 21/21 [==============================] - 2s 84ms/step - loss: 0.1506 - accuracy: 0.9532 - precision: 0.9571 - recall: 0.9497 - val_loss: 0.1377 - val_accuracy: 0.9512 - val_precision: 0.9548 - val_recall: 0.9479
# Epoch 12/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1540 - accuracy: 0.9516 - precision: 0.9551 - recall: 0.9486 - val_loss: 0.1206 - val_accuracy: 0.9584 - val_precision: 0.9600 - val_recall: 0.9574
# Epoch 13/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1581 - accuracy: 0.9494 - precision: 0.9532 - recall: 0.9462 - val_loss: 0.1187 - val_accuracy: 0.9602 - val_precision: 0.9629 - val_recall: 0.9583
# Epoch 14/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1369 - accuracy: 0.9579 - precision: 0.9617 - recall: 0.9547 - val_loss: 0.1342 - val_accuracy: 0.9558 - val_precision: 0.9588 - val_recall: 0.9530
# Epoch 15/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1365 - accuracy: 0.9569 - precision: 0.9605 - recall: 0.9538 - val_loss: 0.1195 - val_accuracy: 0.9594 - val_precision: 0.9618 - val_recall: 0.9578
# Epoch 16/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1273 - accuracy: 0.9597 - precision: 0.9630 - recall: 0.9569 - val_loss: 0.1005 - val_accuracy: 0.9638 - val_precision: 0.9668 - val_recall: 0.9608
# Epoch 17/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1251 - accuracy: 0.9611 - precision: 0.9643 - recall: 0.9583 - val_loss: 0.1126 - val_accuracy: 0.9616 - val_precision: 0.9644 - val_recall: 0.9592
# Epoch 18/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1198 - accuracy: 0.9624 - precision: 0.9657 - recall: 0.9594 - val_loss: 0.1047 - val_accuracy: 0.9634 - val_precision: 0.9656 - val_recall: 0.9611
# Epoch 19/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1164 - accuracy: 0.9632 - precision: 0.9663 - recall: 0.9606 - val_loss: 0.0937 - val_accuracy: 0.9675 - val_precision: 0.9694 - val_recall: 0.9649
# Epoch 20/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1165 - accuracy: 0.9642 - precision: 0.9669 - recall: 0.9617 - val_loss: 0.0947 - val_accuracy: 0.9684 - val_precision: 0.9709 - val_recall: 0.9658
# Epoch 21/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1080 - accuracy: 0.9666 - precision: 0.9694 - recall: 0.9638 - val_loss: 0.1300 - val_accuracy: 0.9591 - val_precision: 0.9607 - val_recall: 0.9568
# Epoch 22/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1106 - accuracy: 0.9659 - precision: 0.9685 - recall: 0.9633 - val_loss: 0.0963 - val_accuracy: 0.9665 - val_precision: 0.9684 - val_recall: 0.9642
# Epoch 23/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1114 - accuracy: 0.9647 - precision: 0.9670 - recall: 0.9622 - val_loss: 0.1071 - val_accuracy: 0.9635 - val_precision: 0.9653 - val_recall: 0.9614
# Epoch 24/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1057 - accuracy: 0.9667 - precision: 0.9688 - recall: 0.9643 - val_loss: 0.1031 - val_accuracy: 0.9672 - val_precision: 0.9688 - val_recall: 0.9661
# Epoch 25/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.1048 - accuracy: 0.9676 - precision: 0.9697 - recall: 0.9652 - val_loss: 0.1065 - val_accuracy: 0.9629 - val_precision: 0.9652 - val_recall: 0.9610
# Epoch 26/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1025 - accuracy: 0.9675 - precision: 0.9700 - recall: 0.9649 - val_loss: 0.0983 - val_accuracy: 0.9681 - val_precision: 0.9698 - val_recall: 0.9657
# Epoch 27/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1005 - accuracy: 0.9684 - precision: 0.9713 - recall: 0.9656 - val_loss: 0.0952 - val_accuracy: 0.9699 - val_precision: 0.9712 - val_recall: 0.9689
# Epoch 28/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.0900 - accuracy: 0.9726 - precision: 0.9749 - recall: 0.9699 - val_loss: 0.0997 - val_accuracy: 0.9696 - val_precision: 0.9709 - val_recall: 0.9675
# Epoch 29/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1097 - accuracy: 0.9665 - precision: 0.9685 - recall: 0.9642 - val_loss: 0.1170 - val_accuracy: 0.9617 - val_precision: 0.9640 - val_recall: 0.9591
# Epoch 30/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1007 - accuracy: 0.9694 - precision: 0.9720 - recall: 0.9667 - val_loss: 0.0941 - val_accuracy: 0.9706 - val_precision: 0.9730 - val_recall: 0.9690
# Epoch 31/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.0957 - accuracy: 0.9706 - precision: 0.9732 - recall: 0.9681 - val_loss: 0.1085 - val_accuracy: 0.9667 - val_precision: 0.9687 - val_recall: 0.9646
# Epoch 32/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.0823 - accuracy: 0.9751 - precision: 0.9767 - recall: 0.9726 - val_loss: 0.1192 - val_accuracy: 0.9668 - val_precision: 0.9680 - val_recall: 0.9655
# Epoch 33/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.0888 - accuracy: 0.9723 - precision: 0.9741 - recall: 0.9701 - val_loss: 0.0958 - val_accuracy: 0.9709 - val_precision: 0.9722 - val_recall: 0.9692
# Epoch 34/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.0798 - accuracy: 0.9756 - precision: 0.9771 - recall: 0.9733 - val_loss: 0.0732 - val_accuracy: 0.9774 - val_precision: 0.9787 - val_recall: 0.9758
# Epoch 35/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.0835 - accuracy: 0.9743 - precision: 0.9759 - recall: 0.9722 - val_loss: 0.0940 - val_accuracy: 0.9698 - val_precision: 0.9721 - val_recall: 0.9679
# Epoch 36/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.0773 - accuracy: 0.9762 - precision: 0.9779 - recall: 0.9738 - val_loss: 0.0761 - val_accuracy: 0.9768 - val_precision: 0.9778 - val_recall: 0.9752
# Epoch 37/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.0757 - accuracy: 0.9774 - precision: 0.9786 - recall: 0.9755 - val_loss: 0.0960 - val_accuracy: 0.9720 - val_precision: 0.9732 - val_recall: 0.9708
# Epoch 38/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.0839 - accuracy: 0.9738 - precision: 0.9753 - recall: 0.9719 - val_loss: 0.0764 - val_accuracy: 0.9775 - val_precision: 0.9791 - val_recall: 0.9759
# Epoch 39/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.0797 - accuracy: 0.9756 - precision: 0.9770 - recall: 0.9735 - val_loss: 0.1016 - val_accuracy: 0.9709 - val_precision: 0.9724 - val_recall: 0.9695
# Epoch 40/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.0756 - accuracy: 0.9769 - precision: 0.9781 - recall: 0.9752 - val_loss: 0.0700 - val_accuracy: 0.9794 - val_precision: 0.9802 - val_recall: 0.9782
# Epoch 41/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.0683 - accuracy: 0.9793 - precision: 0.9803 - recall: 0.9780 - val_loss: 0.0641 - val_accuracy: 0.9811 - val_precision: 0.9820 - val_recall: 0.9801
# Epoch 42/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.0681 - accuracy: 0.9790 - precision: 0.9800 - recall: 0.9780 - val_loss: 0.0810 - val_accuracy: 0.9769 - val_precision: 0.9782 - val_recall: 0.9757
# Epoch 43/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.0724 - accuracy: 0.9778 - precision: 0.9792 - recall: 0.9766 - val_loss: 0.0782 - val_accuracy: 0.9752 - val_precision: 0.9769 - val_recall: 0.9739
# Epoch 44/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.0730 - accuracy: 0.9777 - precision: 0.9790 - recall: 0.9763 - val_loss: 0.0783 - val_accuracy: 0.9752 - val_precision: 0.9764 - val_recall: 0.9743
# Epoch 45/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.0690 - accuracy: 0.9787 - precision: 0.9799 - recall: 0.9775 - val_loss: 0.0729 - val_accuracy: 0.9792 - val_precision: 0.9800 - val_recall: 0.9783
# Epoch 46/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.0670 - accuracy: 0.9796 - precision: 0.9804 - recall: 0.9786 - val_loss: 0.0666 - val_accuracy: 0.9806 - val_precision: 0.9814 - val_recall: 0.9799
# Epoch 47/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.0725 - accuracy: 0.9780 - precision: 0.9789 - recall: 0.9772 - val_loss: 0.0790 - val_accuracy: 0.9765 - val_precision: 0.9772 - val_recall: 0.9757
# Epoch 48/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.0614 - accuracy: 0.9809 - precision: 0.9819 - recall: 0.9801 - val_loss: 0.0730 - val_accuracy: 0.9786 - val_precision: 0.9795 - val_recall: 0.9779
# Epoch 49/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.0591 - accuracy: 0.9818 - precision: 0.9828 - recall: 0.9811 - val_loss: 0.0675 - val_accuracy: 0.9802 - val_precision: 0.9808 - val_recall: 0.9797
# Epoch 50/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.0584 - accuracy: 0.9820 - precision: 0.9826 - recall: 0.9814 - val_loss: 0.0844 - val_accuracy: 0.9776 - val_precision: 0.9783 - val_recall: 0.9771
# Epoch 51/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.0625 - accuracy: 0.9806 - precision: 0.9813 - recall: 0.9799 - val_loss: 0.0698 - val_accuracy: 0.9790 - val_precision: 0.9796 - val_recall: 0.9784
# Epoch 52/60
# 21/21 [==============================] - 2s 88ms/step - loss: 0.0705 - accuracy: 0.9790 - precision: 0.9802 - recall: 0.9781 - val_loss: 0.0648 - val_accuracy: 0.9795 - val_precision: 0.9812 - val_recall: 0.9780
# Epoch 53/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.0838 - accuracy: 0.9722 - precision: 0.9734 - recall: 0.9709 - val_loss: 0.0710 - val_accuracy: 0.9791 - val_precision: 0.9797 - val_recall: 0.9786
# Epoch 54/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.0600 - accuracy: 0.9819 - precision: 0.9827 - recall: 0.9811 - val_loss: 0.0721 - val_accuracy: 0.9798 - val_precision: 0.9804 - val_recall: 0.9792
# Epoch 55/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.0549 - accuracy: 0.9831 - precision: 0.9837 - recall: 0.9825 - val_loss: 0.0805 - val_accuracy: 0.9785 - val_precision: 0.9790 - val_recall: 0.9781
# Epoch 56/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.0620 - accuracy: 0.9812 - precision: 0.9821 - recall: 0.9807 - val_loss: 0.0705 - val_accuracy: 0.9786 - val_precision: 0.9795 - val_recall: 0.9781
# Epoch 57/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.0754 - accuracy: 0.9784 - precision: 0.9794 - recall: 0.9776 - val_loss: 0.0944 - val_accuracy: 0.9683 - val_precision: 0.9689 - val_recall: 0.9677
# Epoch 58/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.0777 - accuracy: 0.9740 - precision: 0.9752 - recall: 0.9732 - val_loss: 0.0710 - val_accuracy: 0.9794 - val_precision: 0.9811 - val_recall: 0.9780
# Epoch 59/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.0668 - accuracy: 0.9790 - precision: 0.9809 - recall: 0.9775 - val_loss: 0.0664 - val_accuracy: 0.9812 - val_precision: 0.9829 - val_recall: 0.9792
# Epoch 60/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.0557 - accuracy: 0.9828 - precision: 0.9839 - recall: 0.9815 - val_loss: 0.0842 - val_accuracy: 0.9778 - val_precision: 0.9786 - val_recall: 0.9770

# %%
def plot_model(history):
    fig, axes = plt.subplots(1, 2, figsize=(10, 5))

    loss = history.history["loss"]
    val_loss = history.history["val_loss"]

    acc = history.history["accuracy"]
    val_acc = history.history["val_accuracy"]

    epochs = range(1, len(loss) + 1)

    axes[0].plot(epochs, loss, "y", label="Training")
    axes[0].plot(epochs, val_loss, "r", label="Validation")
    axes[0].set_xlabel("Epochs")
    axes[0].set_ylabel("Loss")

    axes[1].plot(epochs, acc, "y", label="Training")
    axes[1].plot(epochs, val_acc, "r", label="Validation")
    axes[1].set_xlabel("Epochs")
    axes[1].set_ylabel("Accuracy")
    axes[0].legend()

    axes[0].set_ylim(0.0, 3.0)
    axes[1].set_ylim(0.0, 1.0)

# %%
plot_model(history)
plt.savefig(f"{img_dir}training_loss.png")

# %%
"""
Apply to the test data + display

"""


def plot_predictions(model, images):
    assert len(images) == 16
    X_test = processing.imgs2array(images)

    fig, axes = plt.subplots(4, 4, figsize=(10, 10))
    for image, array, axis in zip(images, X_test, axes.flat):
        # Add a batch axis so the model can interpret the image
        # Find the class with the highest probability
        prediction = np.argmax(
            model.predict(array[np.newaxis, ...], verbose=0), axis=-1
        ).squeeze()

        axis.imshow(image)
        axis.imshow(prediction, alpha=0.5)

        axis.set_xticks([])
        axis.set_yticks([])

    fig.tight_layout()

# %%
test_indices = rng.choice(len(test_images), size=16, replace=False)

plot_predictions(model, test_images[test_indices])
plt.savefig(f"{img_dir}test_predictions.png")

# %%
"""
Now let's try flipping and rotating the images randomly to see how that affects the training

"""

# Crop and flip the images
flipped_train_images, flipped_train_masks = processing.rotate_and_flip(gen, train_images, train_masks)

# Convert them to arrays
X_train_flipped = processing.imgs2array(flipped_train_images)
y_train_flipped = processing.masks2matrix(flipped_train_masks, len(classes))

# %%
"""
Display some of them 

"""

fig, axes = plt.subplots(4, 4, figsize=(10, 10))

for i, ax in zip(indices, axes.flat):
    ax.imshow(flipped_train_images[i], cmap="gray")
    ax.imshow(flipped_train_masks[i], cmap="viridis", alpha=0.5)
    ax.set_xticks([])
    ax.set_yticks([])

fig.suptitle("Training images and masks - flipped")

fig.tight_layout()
fig.savefig(f"{img_dir}flipped_training_images_and_masks.png")

# %%
flipped_model = new_model(**model_params)
flipped_history = flipped_model.fit(X_train_flipped, y_train_flipped, **train_kw)
# Out:
# Epoch 1/60
# 21/21 [==============================] - 5s 101ms/step - loss: 3.0745 - accuracy: 0.2531 - precision_1: 0.2803 - recall_1: 0.0965 - val_loss: 1.3588 - val_accuracy: 0.2101 - val_precision_1: 0.2813 - val_recall_1: 0.2021
# Epoch 2/60
# 21/21 [==============================] - 2s 87ms/step - loss: 1.5959 - accuracy: 0.1994 - precision_1: 0.2687 - recall_1: 0.1956 - val_loss: 1.3041 - val_accuracy: 0.2077 - val_precision_1: 0.2862 - val_recall_1: 0.2046
# Epoch 3/60
# 21/21 [==============================] - 2s 85ms/step - loss: 1.4304 - accuracy: 0.1990 - precision_1: 0.2833 - recall_1: 0.1959 - val_loss: 1.5095 - val_accuracy: 0.2074 - val_precision_1: 0.2890 - val_recall_1: 0.2062
# Epoch 4/60
# 21/21 [==============================] - 2s 85ms/step - loss: 1.2835 - accuracy: 0.2184 - precision_1: 0.3154 - recall_1: 0.2047 - val_loss: 1.1465 - val_accuracy: 0.2189 - val_precision_1: 0.3178 - val_recall_1: 0.2132
# Epoch 5/60
# 21/21 [==============================] - 2s 87ms/step - loss: 1.1156 - accuracy: 0.3401 - precision_1: 0.4766 - recall_1: 0.3050 - val_loss: 0.8042 - val_accuracy: 0.5618 - val_precision_1: 0.7440 - val_recall_1: 0.4739
# Epoch 6/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.9773 - accuracy: 0.5892 - precision_1: 0.6783 - recall_1: 0.5176 - val_loss: 0.5161 - val_accuracy: 0.8464 - val_precision_1: 0.8549 - val_recall_1: 0.8341
# Epoch 7/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.6901 - accuracy: 0.7972 - precision_1: 0.8035 - recall_1: 0.7870 - val_loss: 0.5839 - val_accuracy: 0.8218 - val_precision_1: 0.8262 - val_recall_1: 0.8156
# Epoch 8/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5761 - accuracy: 0.8446 - precision_1: 0.8486 - recall_1: 0.8390 - val_loss: 0.5856 - val_accuracy: 0.8033 - val_precision_1: 0.8054 - val_recall_1: 0.7997
# Epoch 9/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.5238 - accuracy: 0.8629 - precision_1: 0.8652 - recall_1: 0.8598 - val_loss: 0.5145 - val_accuracy: 0.8031 - val_precision_1: 0.8049 - val_recall_1: 0.7999
# Epoch 10/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.4798 - accuracy: 0.8689 - precision_1: 0.8710 - recall_1: 0.8664 - val_loss: 0.2448 - val_accuracy: 0.9267 - val_precision_1: 0.9289 - val_recall_1: 0.9245
# Epoch 11/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5002 - accuracy: 0.8574 - precision_1: 0.8594 - recall_1: 0.8553 - val_loss: 0.3026 - val_accuracy: 0.8966 - val_precision_1: 0.8988 - val_recall_1: 0.8944
# Epoch 12/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5139 - accuracy: 0.8676 - precision_1: 0.8702 - recall_1: 0.8649 - val_loss: 0.7761 - val_accuracy: 0.7035 - val_precision_1: 0.7048 - val_recall_1: 0.7013
# Epoch 13/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.5313 - accuracy: 0.8503 - precision_1: 0.8530 - recall_1: 0.8476 - val_loss: 0.3649 - val_accuracy: 0.8697 - val_precision_1: 0.8724 - val_recall_1: 0.8671
# Epoch 14/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.4098 - accuracy: 0.8799 - precision_1: 0.8822 - recall_1: 0.8780 - val_loss: 0.2258 - val_accuracy: 0.9295 - val_precision_1: 0.9313 - val_recall_1: 0.9282
# Epoch 15/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.3767 - accuracy: 0.8954 - precision_1: 0.8972 - recall_1: 0.8941 - val_loss: 0.3430 - val_accuracy: 0.8791 - val_precision_1: 0.8807 - val_recall_1: 0.8779
# Epoch 16/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.3641 - accuracy: 0.8926 - precision_1: 0.8943 - recall_1: 0.8913 - val_loss: 0.2093 - val_accuracy: 0.9308 - val_precision_1: 0.9326 - val_recall_1: 0.9294
# Epoch 17/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.3213 - accuracy: 0.9085 - precision_1: 0.9101 - recall_1: 0.9074 - val_loss: 0.2265 - val_accuracy: 0.9242 - val_precision_1: 0.9256 - val_recall_1: 0.9234
# Epoch 18/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.3535 - accuracy: 0.8947 - precision_1: 0.8961 - recall_1: 0.8936 - val_loss: 0.2121 - val_accuracy: 0.9277 - val_precision_1: 0.9296 - val_recall_1: 0.9263
# Epoch 19/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.3729 - accuracy: 0.8937 - precision_1: 0.8956 - recall_1: 0.8923 - val_loss: 0.3365 - val_accuracy: 0.8740 - val_precision_1: 0.8760 - val_recall_1: 0.8726
# Epoch 20/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.2903 - accuracy: 0.9143 - precision_1: 0.9164 - recall_1: 0.9131 - val_loss: 0.2785 - val_accuracy: 0.9020 - val_precision_1: 0.9034 - val_recall_1: 0.9011
# Epoch 21/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.2852 - accuracy: 0.9171 - precision_1: 0.9189 - recall_1: 0.9161 - val_loss: 0.1904 - val_accuracy: 0.9344 - val_precision_1: 0.9361 - val_recall_1: 0.9333
# Epoch 22/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.2737 - accuracy: 0.9126 - precision_1: 0.9146 - recall_1: 0.9114 - val_loss: 0.1695 - val_accuracy: 0.9393 - val_precision_1: 0.9416 - val_recall_1: 0.9379
# Epoch 23/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.2439 - accuracy: 0.9268 - precision_1: 0.9289 - recall_1: 0.9255 - val_loss: 0.1884 - val_accuracy: 0.9347 - val_precision_1: 0.9365 - val_recall_1: 0.9336
# Epoch 24/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.2251 - accuracy: 0.9322 - precision_1: 0.9344 - recall_1: 0.9310 - val_loss: 0.1612 - val_accuracy: 0.9437 - val_precision_1: 0.9459 - val_recall_1: 0.9423
# Epoch 25/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.2174 - accuracy: 0.9340 - precision_1: 0.9363 - recall_1: 0.9326 - val_loss: 0.1506 - val_accuracy: 0.9479 - val_precision_1: 0.9502 - val_recall_1: 0.9465
# Epoch 26/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1975 - accuracy: 0.9399 - precision_1: 0.9423 - recall_1: 0.9385 - val_loss: 0.2008 - val_accuracy: 0.9297 - val_precision_1: 0.9320 - val_recall_1: 0.9284
# Epoch 27/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1899 - accuracy: 0.9408 - precision_1: 0.9435 - recall_1: 0.9393 - val_loss: 0.1915 - val_accuracy: 0.9334 - val_precision_1: 0.9360 - val_recall_1: 0.9317
# Epoch 28/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1935 - accuracy: 0.9406 - precision_1: 0.9433 - recall_1: 0.9388 - val_loss: 0.1640 - val_accuracy: 0.9439 - val_precision_1: 0.9460 - val_recall_1: 0.9421
# Epoch 29/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.2031 - accuracy: 0.9388 - precision_1: 0.9413 - recall_1: 0.9369 - val_loss: 0.1586 - val_accuracy: 0.9426 - val_precision_1: 0.9450 - val_recall_1: 0.9404
# Epoch 30/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.1795 - accuracy: 0.9439 - precision_1: 0.9467 - recall_1: 0.9418 - val_loss: 0.1393 - val_accuracy: 0.9490 - val_precision_1: 0.9517 - val_recall_1: 0.9468
# Epoch 31/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1691 - accuracy: 0.9489 - precision_1: 0.9517 - recall_1: 0.9468 - val_loss: 0.1505 - val_accuracy: 0.9469 - val_precision_1: 0.9493 - val_recall_1: 0.9445
# Epoch 32/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1651 - accuracy: 0.9493 - precision_1: 0.9518 - recall_1: 0.9471 - val_loss: 0.1483 - val_accuracy: 0.9473 - val_precision_1: 0.9504 - val_recall_1: 0.9446
# Epoch 33/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.1606 - accuracy: 0.9503 - precision_1: 0.9528 - recall_1: 0.9480 - val_loss: 0.1634 - val_accuracy: 0.9445 - val_precision_1: 0.9471 - val_recall_1: 0.9419
# Epoch 34/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1619 - accuracy: 0.9514 - precision_1: 0.9540 - recall_1: 0.9489 - val_loss: 0.1647 - val_accuracy: 0.9449 - val_precision_1: 0.9477 - val_recall_1: 0.9424
# Epoch 35/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.1539 - accuracy: 0.9522 - precision_1: 0.9548 - recall_1: 0.9497 - val_loss: 0.1503 - val_accuracy: 0.9489 - val_precision_1: 0.9513 - val_recall_1: 0.9465
# Epoch 36/60
# 21/21 [==============================] - 2s 88ms/step - loss: 0.1523 - accuracy: 0.9537 - precision_1: 0.9562 - recall_1: 0.9511 - val_loss: 0.1413 - val_accuracy: 0.9471 - val_precision_1: 0.9495 - val_recall_1: 0.9445
# Epoch 37/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1529 - accuracy: 0.9537 - precision_1: 0.9562 - recall_1: 0.9511 - val_loss: 0.2015 - val_accuracy: 0.9384 - val_precision_1: 0.9414 - val_recall_1: 0.9353
# Epoch 38/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1567 - accuracy: 0.9516 - precision_1: 0.9541 - recall_1: 0.9488 - val_loss: 0.1229 - val_accuracy: 0.9561 - val_precision_1: 0.9585 - val_recall_1: 0.9532
# Epoch 39/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1486 - accuracy: 0.9540 - precision_1: 0.9564 - recall_1: 0.9514 - val_loss: 0.1256 - val_accuracy: 0.9557 - val_precision_1: 0.9583 - val_recall_1: 0.9528
# Epoch 40/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1417 - accuracy: 0.9574 - precision_1: 0.9601 - recall_1: 0.9548 - val_loss: 0.1593 - val_accuracy: 0.9493 - val_precision_1: 0.9514 - val_recall_1: 0.9473
# Epoch 41/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1473 - accuracy: 0.9555 - precision_1: 0.9578 - recall_1: 0.9531 - val_loss: 0.1384 - val_accuracy: 0.9500 - val_precision_1: 0.9529 - val_recall_1: 0.9471
# Epoch 42/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1442 - accuracy: 0.9551 - precision_1: 0.9579 - recall_1: 0.9523 - val_loss: 0.1446 - val_accuracy: 0.9505 - val_precision_1: 0.9525 - val_recall_1: 0.9484
# Epoch 43/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1420 - accuracy: 0.9574 - precision_1: 0.9598 - recall_1: 0.9550 - val_loss: 0.1478 - val_accuracy: 0.9514 - val_precision_1: 0.9535 - val_recall_1: 0.9493
# Epoch 44/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1430 - accuracy: 0.9548 - precision_1: 0.9576 - recall_1: 0.9522 - val_loss: 0.1014 - val_accuracy: 0.9634 - val_precision_1: 0.9653 - val_recall_1: 0.9614
# Epoch 45/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1409 - accuracy: 0.9568 - precision_1: 0.9589 - recall_1: 0.9548 - val_loss: 0.1151 - val_accuracy: 0.9542 - val_precision_1: 0.9571 - val_recall_1: 0.9513
# Epoch 46/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.2065 - accuracy: 0.9389 - precision_1: 0.9416 - recall_1: 0.9360 - val_loss: 0.2039 - val_accuracy: 0.9294 - val_precision_1: 0.9322 - val_recall_1: 0.9265
# Epoch 47/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1608 - accuracy: 0.9510 - precision_1: 0.9532 - recall_1: 0.9488 - val_loss: 0.1426 - val_accuracy: 0.9499 - val_precision_1: 0.9528 - val_recall_1: 0.9470
# Epoch 48/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1372 - accuracy: 0.9568 - precision_1: 0.9595 - recall_1: 0.9541 - val_loss: 0.1190 - val_accuracy: 0.9599 - val_precision_1: 0.9618 - val_recall_1: 0.9582
# Epoch 49/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1270 - accuracy: 0.9605 - precision_1: 0.9630 - recall_1: 0.9582 - val_loss: 0.1244 - val_accuracy: 0.9578 - val_precision_1: 0.9600 - val_recall_1: 0.9558
# Epoch 50/60
# 21/21 [==============================] - 2s 84ms/step - loss: 0.1265 - accuracy: 0.9614 - precision_1: 0.9639 - recall_1: 0.9591 - val_loss: 0.1263 - val_accuracy: 0.9560 - val_precision_1: 0.9586 - val_recall_1: 0.9534
# Epoch 51/60
# 21/21 [==============================] - 2s 85ms/step - loss: 0.1369 - accuracy: 0.9559 - precision_1: 0.9584 - recall_1: 0.9538 - val_loss: 0.1345 - val_accuracy: 0.9569 - val_precision_1: 0.9603 - val_recall_1: 0.9536
# Epoch 52/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1218 - accuracy: 0.9617 - precision_1: 0.9644 - recall_1: 0.9594 - val_loss: 0.1281 - val_accuracy: 0.9602 - val_precision_1: 0.9624 - val_recall_1: 0.9584
# Epoch 53/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1195 - accuracy: 0.9627 - precision_1: 0.9655 - recall_1: 0.9604 - val_loss: 0.1370 - val_accuracy: 0.9555 - val_precision_1: 0.9574 - val_recall_1: 0.9541
# Epoch 54/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1241 - accuracy: 0.9615 - precision_1: 0.9639 - recall_1: 0.9595 - val_loss: 0.1414 - val_accuracy: 0.9520 - val_precision_1: 0.9552 - val_recall_1: 0.9490
# Epoch 55/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1192 - accuracy: 0.9623 - precision_1: 0.9650 - recall_1: 0.9601 - val_loss: 0.1349 - val_accuracy: 0.9570 - val_precision_1: 0.9589 - val_recall_1: 0.9555
# Epoch 56/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1242 - accuracy: 0.9595 - precision_1: 0.9620 - recall_1: 0.9575 - val_loss: 0.1021 - val_accuracy: 0.9638 - val_precision_1: 0.9661 - val_recall_1: 0.9620
# Epoch 57/60
# 21/21 [==============================] - 2s 88ms/step - loss: 0.1155 - accuracy: 0.9634 - precision_1: 0.9659 - recall_1: 0.9615 - val_loss: 0.1166 - val_accuracy: 0.9610 - val_precision_1: 0.9637 - val_recall_1: 0.9587
# Epoch 58/60
# 21/21 [==============================] - 2s 86ms/step - loss: 0.1198 - accuracy: 0.9619 - precision_1: 0.9645 - recall_1: 0.9599 - val_loss: 0.1138 - val_accuracy: 0.9578 - val_precision_1: 0.9601 - val_recall_1: 0.9562
# Epoch 59/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1151 - accuracy: 0.9643 - precision_1: 0.9668 - recall_1: 0.9625 - val_loss: 0.1068 - val_accuracy: 0.9640 - val_precision_1: 0.9660 - val_recall_1: 0.9625
# Epoch 60/60
# 21/21 [==============================] - 2s 87ms/step - loss: 0.1092 - accuracy: 0.9648 - precision_1: 0.9672 - recall_1: 0.9629 - val_loss: 0.1118 - val_accuracy: 0.9643 - val_precision_1: 0.9665 - val_recall_1: 0.9627

# %%
plot_model(flipped_history)
plt.savefig(f"{img_dir}flipped_training_loss.png")

# %%
plot_predictions(flipped_model, test_images[test_indices])
plt.savefig(f"{img_dir}flipped_test_predictions.png")

# %%
"""
Let's ignore the flipped images for now and train the model on the original images - since it's clearly better

Let's try changing the learning rate to see what values we get

"""
from tqdm import tqdm

learning_rates = [0.02, 0.002, 0.0002, 0.00002, 0.000002, 0.0000002]
models = {}
histories = {}

train_kw["verbose"] = 0
for learning_rate in tqdm(learning_rates):
    _model = new_model(dropout=0.0, learning_rate=learning_rate)
    _history = _model.fit(X_train, y_train, **train_kw)
    # plot_model(_history)
    # plt.savefig(f"{img_dir}training_loss_{learning_rate=}.png")

    # plot_predictions(_model, test_images[test_indices])
    # plt.savefig(f"{img_dir}test_predictions_{learning_rate=}.png")

    models[learning_rate] = _model
    histories[learning_rate] = _history
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# 100%|██████████| 6/6 [11:08<00:00, 111.44s/it]

# %%
import pickle
with open(f"models.pkl", "wb") as f:
    pickle.dump(models, f)

# %%
fig, axis = plt.subplots(1, 1)

for learning_rate, history in histories.items():
    axis.plot(
        range(1, len(models[learning_rate].history.history["loss"]) + 1),
        history.history["loss"],
        label=learning_rate,
    )

axis.legend(title="Learning Rate")
axis.set_ylim(0, 5)

fig.suptitle("Training loss for different learning rates")

fig.tight_layout()
fig.savefig(f"{img_dir}learning_rate_comparison.png")

# %%
"""
Let's also plot the accuracy

"""

# The best learning rate
learning_rate = 0.002

fig, axis = plt.subplots(1, 1)

axis.plot(histories[learning_rate].history["accuracy"], label="Training")
axis.plot(histories[learning_rate].history["val_accuracy"], label="Validation")
