# %% [markdown]
# Reproduce Elis' work, for my understanding
#
# It looks like the three relevant bits of code happen in three steps:
# - Define the uNet
# - straighten the images
# - perform segmentation
#
# This notebook does the first of these

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
"""
Resize the images for training

"""
import pathlib
import warnings
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from cementum import processing, util

# We don't have the same number of images and masks, unfortunately
# So we'll just open this many
n_imgs = 516
n_total = 516

# Choose some images and masks at random
gen = np.random.default_rng(0)
indices = gen.choice(np.arange(n_total), size=n_imgs, replace=False)

# Split into training and testing here
train_fraction = 0.8
train_indices = gen.choice(indices, size=int(train_fraction * n_imgs), replace=False)
test_indices = np.array([i for i in indices if i not in train_indices])

data_dir = pathlib.Path("data/original cut/")
mask_dir = pathlib.Path("data/masks cut/")

img_paths = np.array(sorted(tuple(data_dir.glob(r"????.tif"))))
mask_paths = np.array(sorted(tuple(pathlib.Path(mask_dir).glob(r"????.tif"))))

img_size = (320, 320)
train_images = [
    processing.resize(Image.open(str(path)), img_size)
    for path in img_paths[train_indices]
]
test_images = [
    processing.resize(Image.open(str(path)), img_size)
    for path in img_paths[test_indices]
]

# Subtract 1 from masks to make them 0-indexed
train_masks = [
    processing.resize(Image.open(str(path)), img_size) - 1
    for path in mask_paths[train_indices]
]
test_masks = [
    processing.resize(Image.open(str(path)), img_size) - 1
    for path in mask_paths[test_indices]
]

# Check that the masks all contain the right values - and contain all of them (which might be unnecessary)
for i, mask in enumerate(train_masks):
    assert (
        np.unique(mask) == [0, 1, 2]
    ).all(), f"{util.bcolours.FAIL}Mask {i} contains vals {util.bcolours.WARNING}{np.unique(mask)}"

assert len(train_images) == len(train_masks), len(train_images)
if len(train_images) + len(test_images) != n_imgs:
    warnings.warn(
        f"{util.bcolours.WARNING}Only {len(train_images) + len(test_images)} images were loaded"
    )
# Out:
# 2023-12-06 11:21:39.930582: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def plot_images(image, mask):
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    axes[0].imshow(image, cmap="grey")
    axes[1].imshow(mask)

    axes[2].imshow(image, cmap="gray")
    axes[2].imshow(mask, alpha=0.2)

    for axis, title in zip(axes, ("Image", "Mask", "Both")):
        axis.axis("off")
        axis.set_title(title)

    fig.tight_layout()
    
    return fig


idx = 50
fig = plot_images(train_images[idx], train_masks[idx])
fig.suptitle(f"{img_paths[idx]}; {mask_paths[idx]}")
fig.savefig("before_augmentation.png")

# %%
"""
Randomly rotate and flip the images and masks

"""
train_images, train_masks = processing.rotate_and_flip(
    gen, np.array(train_images), np.array(train_masks)
)

fig = plot_images(train_images[idx], train_masks[idx])
fig.suptitle(f"{img_paths[idx]}; {mask_paths[idx]}")
fig.savefig("after_augmentation.png")

# %%
"""
Reshape, normalise and split the data
Also find the class weights

"""
from sklearn.utils import class_weight

classes = np.unique(train_masks)
n_classes = len(classes)
assert (
    n_classes == 3
), "We've already checked this, so if this fails then you're in trouble"

# Rescale images to [0, 1] and reshape
X_train = processing.imgs2array(train_images)

# Convert masks to a binary class matrix
y_train = processing.masks2matrix(train_masks, n_classes)

# Find class weights
print(
    f"Class values in the dataset are ... , {dict(zip(*np.unique(train_masks, return_counts=True)))}"
)
class_weights = class_weight.compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=train_masks.ravel(),
)

class_weights = dict(zip(range(n_classes), class_weights))

print("Class weights are...:", class_weights)
# Out:
# Class values in the dataset are ... , {0: 15391962, 1: 8434602, 2: 18362236}
# Class weights are...: {0: 0.9136543692956969, 1: 1.667290683464772, 2: 0.7658617029719764}

# %%
"""
Define the uNet

"""
from cementum import unet
from keras.optimizers import Adam
from keras.metrics import Precision, Recall

IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]

model = unet.my_unet(
    n_classes=n_classes,
    IMG_HEIGHT=IMG_HEIGHT,
    IMG_WIDTH=IMG_WIDTH,
    IMG_CHANNELS=IMG_CHANNELS,
)

model.compile(
    optimizer=Adam(learning_rate=0.002),
    loss="categorical_crossentropy",
    metrics=["accuracy", Precision(), Recall()],
)

# %%
"""
Either train or open the model

"""
import os
import pickle
from keras.models import load_model


def model_trained(*files):
    for path in files:
        if not os.path.exists(path):
            return False
    return True


# Probably want a batch_size of 32, 64 or 16
# More epochs will probably be better but might overfit
# Want to shuffle the data since nearby images are very similar
train_kw = {"batch_size": 32, "epochs": 25, "verbose": 1, "shuffle": True}

model_path = "cementum_test.keras"
history_path = "cementum_test.history"
data_path = "cementum_data.pickle"

if model_trained(model_path, history_path, data_path):
    model = load_model(model_path)

    with open(history_path, "rb") as history:
        history = pickle.load(history)

    with open(data_path, "rb") as data:
        X_train, y_train, test_images, test_masks = pickle.load(data)

else:
    history = model.fit(
        X_train,
        y_train,
        class_weight=class_weights,
        validation_split=0.2,
        **train_kw,
    )

    model.save(model_path)
    with open(history_path, "wb") as f:
        pickle.dump(history, f)

    with open(data_path, "wb") as f:
        pickle.dump((X_train, y_train, test_images, test_masks), f)
# Out:
# Epoch 1/25
# 11/11 [==============================] - 80s 7s/step - loss: 1.1645 - accuracy: 0.4467 - precision: 0.3660 - recall: 0.0901 - val_loss: 0.9177 - val_accuracy: 0.6031 - val_precision: 0.3558 - val_recall: 0.0075
# Epoch 2/25
# 11/11 [==============================] - 80s 7s/step - loss: 0.7991 - accuracy: 0.7326 - precision: 0.6973 - recall: 0.3423 - val_loss: 0.5378 - val_accuracy: 0.8087 - val_precision: 0.8140 - val_recall: 0.7987
# Epoch 3/25
# 11/11 [==============================] - 79s 7s/step - loss: 0.5503 - accuracy: 0.7911 - precision: 0.7941 - recall: 0.7867 - val_loss: 0.4158 - val_accuracy: 0.8131 - val_precision: 0.8167 - val_recall: 0.8078
# Epoch 4/25
# 11/11 [==============================] - 79s 7s/step - loss: 0.4689 - accuracy: 0.8086 - precision: 0.8157 - recall: 0.7997 - val_loss: 0.4153 - val_accuracy: 0.8371 - val_precision: 0.8451 - val_recall: 0.8270
# Epoch 5/25
# 11/11 [==============================] - 88s 8s/step - loss: 0.4520 - accuracy: 0.8438 - precision: 0.8526 - recall: 0.8338 - val_loss: 0.3654 - val_accuracy: 0.8451 - val_precision: 0.8491 - val_recall: 0.8406
# Epoch 6/25
# 11/11 [==============================] - 82s 7s/step - loss: 0.4033 - accuracy: 0.8545 - precision: 0.8607 - recall: 0.8472 - val_loss: 0.3575 - val_accuracy: 0.8534 - val_precision: 0.8608 - val_recall: 0.8441
# Epoch 7/25
# 11/11 [==============================] - 75s 7s/step - loss: 0.3930 - accuracy: 0.8542 - precision: 0.8611 - recall: 0.8466 - val_loss: 0.3577 - val_accuracy: 0.8612 - val_precision: 0.8724 - val_recall: 0.8473
# Epoch 8/25
# 11/11 [==============================] - 80s 7s/step - loss: 0.3646 - accuracy: 0.8653 - precision: 0.8721 - recall: 0.8573 - val_loss: 0.3113 - val_accuracy: 0.8804 - val_precision: 0.8832 - val_recall: 0.8773
# Epoch 9/25
# 11/11 [==============================] - 78s 7s/step - loss: 0.3547 - accuracy: 0.8662 - precision: 0.8694 - recall: 0.8623 - val_loss: 0.3160 - val_accuracy: 0.8736 - val_precision: 0.8761 - val_recall: 0.8705
# Epoch 10/25
# 11/11 [==============================] - 79s 7s/step - loss: 0.3229 - accuracy: 0.8802 - precision: 0.8831 - recall: 0.8769 - val_loss: 0.2877 - val_accuracy: 0.8838 - val_precision: 0.8870 - val_recall: 0.8798
# Epoch 11/25
# 11/11 [==============================] - 76s 7s/step - loss: 0.3065 - accuracy: 0.8881 - precision: 0.8913 - recall: 0.8843 - val_loss: 0.2962 - val_accuracy: 0.8876 - val_precision: 0.8902 - val_recall: 0.8845
# Epoch 12/25
# 11/11 [==============================] - 78s 7s/step - loss: 0.2910 - accuracy: 0.8906 - precision: 0.8936 - recall: 0.8872 - val_loss: 0.2684 - val_accuracy: 0.8949 - val_precision: 0.8975 - val_recall: 0.8917
# Epoch 13/25
# 11/11 [==============================] - 75s 7s/step - loss: 0.2728 - accuracy: 0.8974 - precision: 0.9003 - recall: 0.8944 - val_loss: 0.2557 - val_accuracy: 0.8987 - val_precision: 0.9022 - val_recall: 0.8949
# Epoch 14/25
# 11/11 [==============================] - 73s 7s/step - loss: 0.2566 - accuracy: 0.8934 - precision: 0.8968 - recall: 0.8900 - val_loss: 0.2533 - val_accuracy: 0.8975 - val_precision: 0.9012 - val_recall: 0.8944
# Epoch 15/25
# 11/11 [==============================] - 75s 7s/step - loss: 0.2507 - accuracy: 0.9007 - precision: 0.9041 - recall: 0.8974 - val_loss: 0.3695 - val_accuracy: 0.8436 - val_precision: 0.8460 - val_recall: 0.8410
# Epoch 16/25
# 11/11 [==============================] - 74s 7s/step - loss: 0.2677 - accuracy: 0.8891 - precision: 0.8937 - recall: 0.8844 - val_loss: 0.2505 - val_accuracy: 0.9015 - val_precision: 0.9078 - val_recall: 0.8951
# Epoch 17/25
# 11/11 [==============================] - 73s 7s/step - loss: 0.2438 - accuracy: 0.9029 - precision: 0.9063 - recall: 0.8991 - val_loss: 0.2403 - val_accuracy: 0.9080 - val_precision: 0.9122 - val_recall: 0.9034
# Epoch 18/25
# 11/11 [==============================] - 70s 6s/step - loss: 0.2427 - accuracy: 0.9048 - precision: 0.9081 - recall: 0.9011 - val_loss: 0.2271 - val_accuracy: 0.9066 - val_precision: 0.9106 - val_recall: 0.9018
# Epoch 19/25
# 11/11 [==============================] - 69s 6s/step - loss: 0.2294 - accuracy: 0.9088 - precision: 0.9126 - recall: 0.9047 - val_loss: 0.2351 - val_accuracy: 0.8970 - val_precision: 0.8994 - val_recall: 0.8936
# Epoch 20/25
# 11/11 [==============================] - 74s 7s/step - loss: 0.2458 - accuracy: 0.9039 - precision: 0.9064 - recall: 0.9011 - val_loss: 0.2328 - val_accuracy: 0.9016 - val_precision: 0.9045 - val_recall: 0.8988
# Epoch 21/25
# 11/11 [==============================] - 70s 6s/step - loss: 0.2235 - accuracy: 0.9070 - precision: 0.9100 - recall: 0.9040 - val_loss: 0.2177 - val_accuracy: 0.9109 - val_precision: 0.9137 - val_recall: 0.9082
# Epoch 22/25
# 11/11 [==============================] - 71s 6s/step - loss: 0.2199 - accuracy: 0.9118 - precision: 0.9141 - recall: 0.9089 - val_loss: 0.2288 - val_accuracy: 0.9063 - val_precision: 0.9079 - val_recall: 0.9037
# Epoch 23/25
# 11/11 [==============================] - 91s 8s/step - loss: 0.2211 - accuracy: 0.9127 - precision: 0.9145 - recall: 0.9092 - val_loss: 0.2152 - val_accuracy: 0.9155 - val_precision: 0.9167 - val_recall: 0.9135
# Epoch 24/25
# 11/11 [==============================] - 84s 8s/step - loss: 0.2181 - accuracy: 0.9126 - precision: 0.9146 - recall: 0.9091 - val_loss: 0.2211 - val_accuracy: 0.9076 - val_precision: 0.9087 - val_recall: 0.9058
# Epoch 25/25
# 11/11 [==============================] - 75s 7s/step - loss: 0.2051 - accuracy: 0.9168 - precision: 0.9182 - recall: 0.9145 - val_loss: 0.2003 - val_accuracy: 0.9194 - val_precision: 0.9207 - val_recall: 0.9179

# %%
"""
Plot the loss and validation accuracy at each epoch

"""
loss = history.history["loss"]
val_loss = history.history["val_loss"]

acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

epochs = range(1, len(loss) + 1)

fig, axes = plt.subplots(1, 2)
axes[0].plot(epochs, loss, "y", label="Training")
axes[0].plot(epochs, val_loss, "r", label="Validation")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Loss")

axes[1].plot(epochs, acc, "y", label="Training")
axes[1].plot(epochs, val_acc, "y", label="Validation")
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("Accuracy")
axes[0].legend()

fig.savefig("training.png")

# %%
"""
Calculate intersection over union for each class using the test set

"""
from keras.metrics import MeanIoU

X_test = processing.imgs2array(np.array(test_images))
y_test = processing.masks2matrix(np.array(test_masks), n_classes)

IOU_keras = MeanIoU(num_classes=n_classes)
IOU_keras.update_state(y_test[:, :, :, 0], model.predict(X_test).argmax(axis=3))


def calculate_iou(values, class_idx):
    iou = values[class_idx, class_idx] / (
        values[class_idx, :].sum()
        + values[:, class_idx].sum()
        - values[class_idx, class_idx]
    )
    return iou


values = np.array(IOU_keras.get_weights()).reshape(n_classes, n_classes)

for i in range(n_classes):
    class_iou = calculate_iou(values, i)
    print(f"IoU for class {i} is: ", class_iou)
# Out:
# 4/4 [==============================] - 5s 1s/step
# IoU for class 0 is:  0.0052067074
# IoU for class 1 is:  0.012883551
# IoU for class 2 is:  0.0

# %%
""" Show the prediction for some of the training images """
from matplotlib.colors import ListedColormap


def preprocess_image(image):
    # Add batch axis
    return image[np.newaxis, ...]


# Choose some images and masks at random
fig, axes = plt.subplots(3, 4, figsize=(16, 12))
indices = np.random.randint(0, len(X_train), size=len(axes.ravel()))


def plot_predictions(axes, indices, images):
    cmap = ListedColormap(["teal", "magenta", "gold"])

    for index, axis in zip(indices, axes.ravel()):
        prediction = np.argmax(
            model.predict(preprocess_image(images[index]), verbose=0), axis=-1
        ).squeeze()
        axis.set_title(f"Image {index}")
        axis.imshow(images[index], cmap="gray")
        axis.imshow(prediction, cmap=cmap, alpha=0.3)


plot_predictions(axes, indices, X_train)
fig.suptitle("Train Images")
fig.tight_layout()

fig.savefig("training_predictions.png")

# %%
""" Show the prediction for some test images """

# Choose some images at random
indices = np.random.randint(0, len(X_test), size=len(axes.ravel()))

fig, axes = plt.subplots(3, 4, figsize=(16, 12))
plot_predictions(axes, indices, X_test)

fig.suptitle("Test Images")
fig.tight_layout()
fig.savefig("test_predictions.png")

# %%
"""
Plot the testing masks and predictions for a single image

"""
fig, axes = plt.subplots(3, 4, figsize=(16, 12))

for index, axis in zip(indices, axes.ravel()):
    axis.set_title(f"Image {index}")
    prediction = np.argmax(
        model.predict(preprocess_image(test_images[index]), verbose=0), axis=-1
    ).squeeze()
    axis.imshow(test_masks[index], cmap=ListedColormap(["white", "green", "red"]), alpha=0.3)
    axis.imshow(prediction, cmap=ListedColormap(["white", "green", "red"]), alpha=0.3)

fig.suptitle("Test Images")
fig.tight_layout()
