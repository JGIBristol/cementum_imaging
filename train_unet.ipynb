# %% [markdown]
# Reproduce Elis' work, for my understanding
#
# It looks like the three relevant bits of code happen in three steps:
# - Define the uNet
# - straighten the images
# - perform segmentation
#
# This notebook does the first of these

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
"""
Resize the images for training

"""
import pathlib
import warnings
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from cementum import processing, util

# We don't have the same number of images and masks, unfortunately
# So we'll just open this many
n_imgs = 516
n_total = 516

# Choose some images and masks at random
gen = np.random.default_rng(0)
indices = gen.choice(np.arange(n_total), size=n_imgs, replace=False)

# Split into training and testing here
train_fraction = 0.8
train_indices = gen.choice(indices, size=int(train_fraction * n_imgs), replace=False)
test_indices = np.array([i for i in indices if i not in train_indices])

data_dir = pathlib.Path("data/original cut/")
mask_dir = pathlib.Path("data/masks cut/")

img_paths = np.array(sorted(tuple(data_dir.glob(r"????.tif"))))
mask_paths = np.array(sorted(tuple(pathlib.Path(mask_dir).glob(r"????.tif"))))

img_size = (320, 320)
train_images = [
    processing.resize(Image.open(str(path)), img_size)
    for path in img_paths[train_indices]
]
test_images = [
    processing.resize(Image.open(str(path)), img_size)
    for path in img_paths[test_indices]
]

# Subtract 1 from masks to make them 0-indexed
train_masks = [
    processing.resize(Image.open(str(path)), img_size) - 1
    for path in mask_paths[train_indices]
]
test_masks = [
    processing.resize(Image.open(str(path)), img_size) - 1
    for path in mask_paths[test_indices]
]

# Check that the masks all contain the right values - and contain all of them (which might be unnecessary)
for i, mask in enumerate(train_masks):
    assert (
        np.unique(mask) == [0, 1, 2]
    ).all(), f"{util.bcolours.FAIL}Mask {i} contains vals {util.bcolours.WARNING}{np.unique(mask)}"

assert len(train_images) == len(train_masks), len(train_images)
if len(train_images) + len(test_images) != n_imgs:
    warnings.warn(
        f"{util.bcolours.WARNING}Only {len(train_images) + len(test_images)} images were loaded"
    )
# Out:
# 2023-12-08 13:07:54.735682: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def plot_images(image, mask):
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    axes[0].imshow(image, cmap="grey")
    axes[1].imshow(mask)

    axes[2].imshow(image, cmap="gray")
    axes[2].imshow(mask, alpha=0.2)

    for axis, title in zip(axes, ("Image", "Mask", "Both")):
        axis.axis("off")
        axis.set_title(title)

    fig.tight_layout()
    
    return fig


idx = 25
fig = plot_images(train_images[idx], train_masks[idx])
fig.suptitle(f"{img_paths[idx]}; {mask_paths[idx]}")
fig.savefig("before_augmentation.png")

# %%
"""
Randomly rotate and flip the images and masks

"""
train_images, train_masks = processing.rotate_and_flip(
    gen, np.array(train_images), np.array(train_masks)
)

fig = plot_images(train_images[idx], train_masks[idx])
fig.suptitle(f"{img_paths[idx]}; {mask_paths[idx]}")
fig.savefig("after_augmentation.png")

# %%
"""
Reshape, normalise and split the data
Also find the class weights

"""
from sklearn.utils import class_weight

classes = np.unique(train_masks)
n_classes = len(classes)
assert (
    n_classes == 3
), "We've already checked this, so if this fails then you're in trouble"

# Rescale images to [0, 1] and reshape
X_train = processing.imgs2array(train_images)

# Convert masks to a binary class matrix
y_train = processing.masks2matrix(train_masks, n_classes)

# Find class weights
print(
    f"Class values in the dataset are ... , {dict(zip(*np.unique(train_masks, return_counts=True)))}"
)
class_weights = class_weight.compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=train_masks.ravel(),
)

class_weights = dict(zip(range(n_classes), class_weights))
print("Class weights are...:", class_weights)

# Increase class weight for dentine, since the other classes are less important
class_weights[2] *=2
print("Class weights are...:", class_weights)

# Increase class weight for cementum, since that's what we care about
class_weights[1] *= 8
print("Class weights are...:", class_weights)
# Out:
# Class values in the dataset are ... , {0: 15391962, 1: 8434602, 2: 18362236}
# Class weights are...: {0: 0.9136543692956969, 1: 1.667290683464772, 2: 0.7658617029719764}
# Class weights are...: {0: 0.9136543692956969, 1: 1.667290683464772, 2: 1.5317234059439528}
# Class weights are...: {0: 0.9136543692956969, 1: 16.67290683464772, 2: 1.5317234059439528}

# %%
"""
Define the uNet

"""
from cementum import unet
from keras.optimizers import Adam
from keras.metrics import Precision, Recall

IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]

model = unet.my_unet(
    n_classes=n_classes,
    IMG_HEIGHT=IMG_HEIGHT,
    IMG_WIDTH=IMG_WIDTH,
    IMG_CHANNELS=IMG_CHANNELS,
)

model.compile(
    optimizer=Adam(learning_rate=0.002),
    loss="categorical_crossentropy",
    metrics=["accuracy", Precision(), Recall()],
)

# %%
"""
Either train or open the model

"""
import os
import pickle
from keras.models import load_model


def model_trained(*files):
    for path in files:
        if not os.path.exists(path):
            return False
    return True


# Probably want a batch_size of 32, 64 or 16
# More epochs will probably be better but might overfit
# Want to shuffle the data since nearby images are very similar
train_kw = {"batch_size": 32, "epochs": 25, "verbose": 1, "shuffle": True}

model_path = "cementum_test.keras"
history_path = "cementum_test.history"
data_path = "cementum_data.pickle"

if model_trained(model_path, history_path, data_path):
    model = load_model(model_path)

    with open(history_path, "rb") as history:
        history = pickle.load(history)

    with open(data_path, "rb") as data:
        X_train, y_train, test_images, test_masks = pickle.load(data)

else:
    with open(data_path, "wb") as f:
        pickle.dump((X_train, y_train, test_images, test_masks), f)
    print("Data cached")

    history = model.fit(
        X_train,
        y_train,
        class_weight=class_weights,
        validation_split=0.2,
        **train_kw,
    )

    model.save(model_path)
    with open(history_path, "wb") as f:
        pickle.dump(history, f)
# Out:
# Data cached
# Epoch 1/25
# 11/11 [==============================] - 68s 6s/step - loss: 6.3198 - accuracy: 0.2060 - precision: 0.2134 - recall: 0.1111 - val_loss: 1.0532 - val_accuracy: 0.2065 - val_precision: 0.2644 - val_recall: 0.1540
# Epoch 2/25
# 11/11 [==============================] - 76s 7s/step - loss: 3.1040 - accuracy: 0.1991 - precision: 0.2600 - recall: 0.1514 - val_loss: 1.3141 - val_accuracy: 0.2077 - val_precision: 0.2754 - val_recall: 0.1661
# Epoch 3/25
# 11/11 [==============================] - 79s 7s/step - loss: 2.9575 - accuracy: 0.1995 - precision: 0.2677 - recall: 0.1597 - val_loss: 1.1795 - val_accuracy: 0.2077 - val_precision: 0.2797 - val_recall: 0.1701
# Epoch 4/25
# 11/11 [==============================] - 75s 7s/step - loss: 2.8637 - accuracy: 0.1992 - precision: 0.2719 - recall: 0.1644 - val_loss: 1.1998 - val_accuracy: 0.2076 - val_precision: 0.2848 - val_recall: 0.1747
# Epoch 5/25
# 11/11 [==============================] - 73s 7s/step - loss: 2.7089 - accuracy: 0.1999 - precision: 0.2283 - recall: 0.1861 - val_loss: 1.1972 - val_accuracy: 0.2073 - val_precision: 0.2081 - val_recall: 0.2071
# Epoch 6/25
# 11/11 [==============================] - 71s 6s/step - loss: 2.4208 - accuracy: 0.2155 - precision: 0.2160 - recall: 0.2147 - val_loss: 0.8501 - val_accuracy: 0.4804 - val_precision: 0.4796 - val_recall: 0.4787
# Epoch 7/25
# 11/11 [==============================] - 70s 6s/step - loss: 2.1177 - accuracy: 0.3378 - precision: 0.3368 - recall: 0.3344 - val_loss: 0.7482 - val_accuracy: 0.6785 - val_precision: 0.6741 - val_recall: 0.6425
# Epoch 8/25
# 11/11 [==============================] - 72s 6s/step - loss: 1.8736 - accuracy: 0.5577 - precision: 0.5581 - recall: 0.5545 - val_loss: 0.6993 - val_accuracy: 0.7496 - val_precision: 0.7497 - val_recall: 0.7494
# Epoch 9/25
# 11/11 [==============================] - 73s 7s/step - loss: 1.7008 - accuracy: 0.6692 - precision: 0.6695 - recall: 0.6685 - val_loss: 0.8039 - val_accuracy: 0.6978 - val_precision: 0.6983 - val_recall: 0.6976
# Epoch 10/25
# 11/11 [==============================] - 71s 6s/step - loss: 1.5989 - accuracy: 0.6894 - precision: 0.6897 - recall: 0.6887 - val_loss: 0.5633 - val_accuracy: 0.7799 - val_precision: 0.7802 - val_recall: 0.7794
# Epoch 11/25
# 11/11 [==============================] - 79s 7s/step - loss: 1.4447 - accuracy: 0.7275 - precision: 0.7277 - recall: 0.7271 - val_loss: 0.6720 - val_accuracy: 0.7387 - val_precision: 0.7388 - val_recall: 0.7385
# Epoch 12/25
# 11/11 [==============================] - 79s 7s/step - loss: 1.3899 - accuracy: 0.7327 - precision: 0.7329 - recall: 0.7324 - val_loss: 0.5557 - val_accuracy: 0.7680 - val_precision: 0.7682 - val_recall: 0.7676
# Epoch 13/25
# 11/11 [==============================] - 75s 7s/step - loss: 1.3593 - accuracy: 0.7383 - precision: 0.7385 - recall: 0.7378 - val_loss: 0.6790 - val_accuracy: 0.6954 - val_precision: 0.6956 - val_recall: 0.6947
# Epoch 14/25
# 11/11 [==============================] - 78s 7s/step - loss: 1.3081 - accuracy: 0.7394 - precision: 0.7397 - recall: 0.7389 - val_loss: 0.4888 - val_accuracy: 0.8001 - val_precision: 0.8006 - val_recall: 0.7994
# Epoch 15/25
# 11/11 [==============================] - 76s 7s/step - loss: 1.2711 - accuracy: 0.7625 - precision: 0.7628 - recall: 0.7619 - val_loss: 0.4174 - val_accuracy: 0.8346 - val_precision: 0.8352 - val_recall: 0.8338
# Epoch 16/25
# 11/11 [==============================] - 75s 7s/step - loss: 1.3098 - accuracy: 0.7634 - precision: 0.7638 - recall: 0.7627 - val_loss: 0.7738 - val_accuracy: 0.7242 - val_precision: 0.7245 - val_recall: 0.7237
# Epoch 17/25
# 11/11 [==============================] - 76s 7s/step - loss: 1.2506 - accuracy: 0.7604 - precision: 0.7607 - recall: 0.7599 - val_loss: 0.4828 - val_accuracy: 0.8034 - val_precision: 0.8037 - val_recall: 0.8030
# Epoch 18/25
# 11/11 [==============================] - 73s 7s/step - loss: 1.1415 - accuracy: 0.7876 - precision: 0.7878 - recall: 0.7873 - val_loss: 0.5535 - val_accuracy: 0.7747 - val_precision: 0.7749 - val_recall: 0.7744
# Epoch 19/25
# 11/11 [==============================] - 75s 7s/step - loss: 1.0736 - accuracy: 0.7912 - precision: 0.7914 - recall: 0.7909 - val_loss: 0.4264 - val_accuracy: 0.8193 - val_precision: 0.8196 - val_recall: 0.8188
# Epoch 20/25
# 11/11 [==============================] - 81s 7s/step - loss: 0.9927 - accuracy: 0.8146 - precision: 0.8149 - recall: 0.8141 - val_loss: 0.4253 - val_accuracy: 0.8111 - val_precision: 0.8117 - val_recall: 0.8103
# Epoch 21/25
# 11/11 [==============================] - 83s 8s/step - loss: 0.9586 - accuracy: 0.8199 - precision: 0.8205 - recall: 0.8191 - val_loss: 0.4006 - val_accuracy: 0.8136 - val_precision: 0.8143 - val_recall: 0.8127
# Epoch 22/25
# 11/11 [==============================] - 98s 9s/step - loss: 0.9046 - accuracy: 0.8173 - precision: 0.8181 - recall: 0.8162 - val_loss: 0.3889 - val_accuracy: 0.8496 - val_precision: 0.8503 - val_recall: 0.8489
# Epoch 23/25
# 11/11 [==============================] - 91s 8s/step - loss: 1.1419 - accuracy: 0.7642 - precision: 0.7649 - recall: 0.7631 - val_loss: 0.5052 - val_accuracy: 0.7598 - val_precision: 0.7607 - val_recall: 0.7584
# Epoch 24/25
# 11/11 [==============================] - 88s 8s/step - loss: 0.9834 - accuracy: 0.8133 - precision: 0.8145 - recall: 0.8116 - val_loss: 0.3286 - val_accuracy: 0.8728 - val_precision: 0.8738 - val_recall: 0.8714
# Epoch 25/25
# 11/11 [==============================] - 96s 9s/step - loss: 0.9050 - accuracy: 0.8466 - precision: 0.8475 - recall: 0.8455 - val_loss: 0.5248 - val_accuracy: 0.7770 - val_precision: 0.7776 - val_recall: 0.7757

# %%
"""
Plot the loss and validation accuracy at each epoch

"""
loss = history.history["loss"]
val_loss = history.history["val_loss"]

acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

epochs = range(1, len(loss) + 1)

fig, axes = plt.subplots(1, 2)
axes[0].plot(epochs, loss, "y", label="Training")
axes[0].plot(epochs, val_loss, "r", label="Validation")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Loss")

axes[1].plot(epochs, acc, "y", label="Training")
axes[1].plot(epochs, val_acc, "r", label="Validation")
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("Accuracy")
axes[0].legend()

fig.savefig("training.png")

# %%
"""
Calculate intersection over union for each class using the test set

"""
from keras.metrics import MeanIoU

X_test = processing.imgs2array(np.array(test_images))
y_test = processing.masks2matrix(np.array(test_masks), n_classes)

IOU_keras = MeanIoU(num_classes=n_classes)
IOU_keras.update_state(y_test[:, :, :, 0], model.predict(X_test).argmax(axis=3))


def calculate_iou(values, class_idx):
    iou = values[class_idx, class_idx] / (
        values[class_idx, :].sum()
        + values[:, class_idx].sum()
        - values[class_idx, class_idx]
    )
    return iou


values = np.array(IOU_keras.get_weights()).reshape(n_classes, n_classes)

for i in range(n_classes):
    class_iou = calculate_iou(values, i)
    print(f"IoU for class {i} is: ", class_iou)
# Out:
# 4/4 [==============================] - 5s 1s/step
# IoU for class 0 is:  0.0002661976
# IoU for class 1 is:  0.047832936
# IoU for class 2 is:  0.0

# %%
""" Show the prediction for some of the training images """
from matplotlib.colors import ListedColormap


def preprocess_image(image):
    # Add batch axis
    return image[np.newaxis, ...]


# Choose some images and masks at random
fig, axes = plt.subplots(3, 4, figsize=(16, 12))
indices = np.random.randint(0, len(X_train), size=len(axes.ravel()))


def plot_predictions(axes, indices, images):
    cmap = ListedColormap(["teal", "magenta", "gold"])

    for index, axis in zip(indices, axes.ravel()):
        prediction = np.argmax(
            model.predict(preprocess_image(images[index]), verbose=0), axis=-1
        ).squeeze()
        axis.set_title(f"Image {index}")
        axis.imshow(images[index], cmap="gray")
        axis.imshow(prediction, cmap=cmap, alpha=0.3)


plot_predictions(axes, indices, X_train)
fig.suptitle("Train Images")
fig.tight_layout()

fig.savefig("training_predictions.png")

# %%
""" Show the prediction for some test images """

# Choose some images at random
indices = np.random.randint(0, len(X_test), size=len(axes.ravel()))

fig, axes = plt.subplots(3, 4, figsize=(16, 12))
plot_predictions(axes, indices, X_test)

fig.suptitle("Test Images")
fig.tight_layout()
fig.savefig("test_predictions.png")

# %%
"""
Plot the testing masks and predictions for a single image

"""
fig, axes = plt.subplots(3, 4, figsize=(16, 12))

for index, axis in zip(indices, axes.ravel()):
    axis.set_title(f"Image {index}")
    prediction = np.argmax(
        model.predict(preprocess_image(test_images[index]), verbose=0), axis=-1
    ).squeeze()
    axis.imshow(test_masks[index], cmap=ListedColormap(["white", "green", "red"]), alpha=0.3)
    mappable = axis.imshow(prediction, cmap=ListedColormap(["white", "green", "red"]), alpha=0.3)


fig.suptitle("Test Images")
fig.tight_layout()

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(mappable, cax=cbar_ax)
