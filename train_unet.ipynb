# %% [markdown]
# Reproduce Elis' work, for my understanding
#
# It looks like the three relevant bits of code happen in three steps:
# - Define the uNet
# - straighten the images
# - perform segmentation
#
# This notebook does the first of these

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
"""
Resize the images for training

"""
import pathlib
import warnings
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from cementum import processing, util

# We don't have the same number of images and masks, unfortunately
# So we'll just open this many
n_imgs = 516
n_total = 516

# Choose some images and masks at random
gen = np.random.default_rng(0)
indices = gen.choice(np.arange(n_total), size=n_imgs, replace=False)

# Split into training and testing here
train_fraction = 0.8
train_indices = gen.choice(indices, size=int(train_fraction * n_imgs), replace=False)
test_indices = np.array([i for i in indices if i not in train_indices])

data_dir = pathlib.Path("data/original cut/")
mask_dir = pathlib.Path("data/masks cut/")

img_paths = np.array(sorted(tuple(data_dir.glob(r"????.tif"))))
mask_paths = np.array(sorted(tuple(pathlib.Path(mask_dir).glob(r"????.tif"))))

img_size = (320, 320)
train_images = [
    processing.resize(Image.open(str(path)), img_size)
    for path in img_paths[train_indices]
]
test_images = [
    processing.resize(Image.open(str(path)), img_size)
    for path in img_paths[test_indices]
]

# Subtract 1 from masks to make them 0-indexed
train_masks = [
    processing.resize(Image.open(str(path)), img_size) - 1
    for path in mask_paths[train_indices]
]
test_masks = [
    processing.resize(Image.open(str(path)), img_size) - 1
    for path in mask_paths[test_indices]
]

# Check that the masks all contain the right values - and contain all of them (which might be unnecessary)
for i, mask in enumerate(train_masks):
    assert (
        np.unique(mask) == [0, 1, 2]
    ).all(), f"{util.bcolours.FAIL}Mask {i} contains vals {util.bcolours.WARNING}{np.unique(mask)}"

assert len(train_images) == len(train_masks), len(train_images)
if len(train_images) + len(test_images) != n_imgs:
    warnings.warn(
        f"{util.bcolours.WARNING}Only {len(train_images) + len(test_images)} images were loaded"
    )
# Out:
# 2023-12-08 13:44:18.235281: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def plot_images(image, mask):
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    axes[0].imshow(image, cmap="grey")
    axes[1].imshow(mask)

    axes[2].imshow(image, cmap="gray")
    axes[2].imshow(mask, alpha=0.2)

    for axis, title in zip(axes, ("Image", "Mask", "Both")):
        axis.axis("off")
        axis.set_title(title)

    fig.tight_layout()
    
    return fig


idx = 25
fig = plot_images(train_images[idx], train_masks[idx])
fig.suptitle(f"{img_paths[idx]}; {mask_paths[idx]}")
fig.savefig("before_augmentation.png")

# %%
"""
Randomly rotate and flip the images and masks

"""
train_images, train_masks = processing.rotate_and_flip(
    gen, np.array(train_images), np.array(train_masks)
)

fig = plot_images(train_images[idx], train_masks[idx])
fig.suptitle(f"{img_paths[idx]}; {mask_paths[idx]}")
fig.savefig("after_augmentation.png")

# %%
"""
Reshape, normalise and split the data
Also find the class weights

"""
from sklearn.utils import class_weight

classes = np.unique(train_masks)
n_classes = len(classes)
assert (
    n_classes == 3
), "We've already checked this, so if this fails then you're in trouble"

# Rescale images to [0, 1] and reshape
X_train = processing.imgs2array(train_images)

# Convert masks to a binary class matrix
y_train = processing.masks2matrix(train_masks, n_classes)

# Find class weights
print(
    f"Class values in the dataset are ... , {dict(zip(*np.unique(train_masks, return_counts=True)))}"
)
class_weights = class_weight.compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=train_masks.ravel(),
)

class_weights = dict(zip(range(n_classes), class_weights))
print("Class weights are...:", class_weights)

# Increase class weight for dentine, since the other classes are less important
class_weights[2] *=2
print("Class weights are...:", class_weights)

# Increase class weight for cementum, since that's what we care about
class_weights[1] *= 8
print("Class weights are...:", class_weights)
# Out:
# Class values in the dataset are ... , {0: 15391962, 1: 8434602, 2: 18362236}
# Class weights are...: {0: 0.9136543692956969, 1: 1.667290683464772, 2: 0.7658617029719764}
# Class weights are...: {0: 0.9136543692956969, 1: 1.667290683464772, 2: 1.5317234059439528}
# Class weights are...: {0: 0.9136543692956969, 1: 13.338325467718176, 2: 1.5317234059439528}

# %%
"""
Define the uNet

"""
from cementum import unet
from keras.optimizers import Adam
from keras.metrics import Precision, Recall

IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]

model = unet.my_unet(
    n_classes=n_classes,
    IMG_HEIGHT=IMG_HEIGHT,
    IMG_WIDTH=IMG_WIDTH,
    IMG_CHANNELS=IMG_CHANNELS,
)

model.compile(
    optimizer=Adam(learning_rate=0.002),
    loss="categorical_crossentropy",
    metrics=["accuracy", Precision(), Recall()],
)

# %%
"""
Either train or open the model

"""
import os
import pickle
from keras.models import load_model


def model_trained(*files):
    for path in files:
        if not os.path.exists(path):
            return False
    return True


# Probably want a batch_size of 32, 64 or 16
# More epochs will probably be better but might overfit
# Want to shuffle the data since nearby images are very similar
train_kw = {"batch_size": 32, "epochs": 25, "verbose": 1, "shuffle": True}

model_path = "cementum_test.keras"
history_path = "cementum_test.history"
data_path = "cementum_data.pickle"

if model_trained(model_path, history_path, data_path):
    model = load_model(model_path)

    with open(history_path, "rb") as history:
        history = pickle.load(history)

    with open(data_path, "rb") as data:
        X_train, y_train, test_images, test_masks = pickle.load(data)

else:
    with open(data_path, "wb") as f:
        pickle.dump((X_train, y_train, test_images, test_masks), f)
    print("Data cached")

    history = model.fit(
        X_train,
        y_train,
        class_weight=class_weights,
        validation_split=0.2,
        **train_kw,
    )

    model.save(model_path)
    with open(history_path, "wb") as f:
        pickle.dump(history, f)
# Out:
# Data cached
# Epoch 1/25
# 11/11 [==============================] - 74s 7s/step - loss: 2.7592 - accuracy: 0.2304 - precision: 0.3211 - recall: 0.1892 - val_loss: 1.0429 - val_accuracy: 0.2077 - val_precision: 0.3083 - val_recall: 0.2057
# Epoch 2/25
# 11/11 [==============================] - 79s 7s/step - loss: 2.0524 - accuracy: 0.2222 - precision: 0.3327 - recall: 0.2204 - val_loss: 0.9148 - val_accuracy: 0.2069 - val_precision: 0.3092 - val_recall: 0.2036
# Epoch 3/25
# 11/11 [==============================] - 78s 7s/step - loss: 1.9749 - accuracy: 0.2058 - precision: 0.3021 - recall: 0.2033 - val_loss: 0.8696 - val_accuracy: 0.2828 - val_precision: 0.4200 - val_recall: 0.2792
# Epoch 4/25
# 11/11 [==============================] - 82s 7s/step - loss: 1.8301 - accuracy: 0.3570 - precision: 0.5270 - recall: 0.3531 - val_loss: 0.9515 - val_accuracy: 0.4911 - val_precision: 0.6449 - val_recall: 0.4874
# Epoch 5/25
# 11/11 [==============================] - 77s 7s/step - loss: 1.5937 - accuracy: 0.4715 - precision: 0.4668 - recall: 0.3379 - val_loss: 0.6793 - val_accuracy: 0.8054 - val_precision: 0.7481 - val_recall: 0.5288
# Epoch 6/25
# 11/11 [==============================] - 77s 7s/step - loss: 1.3202 - accuracy: 0.7516 - precision: 0.7399 - recall: 0.6780 - val_loss: 0.6005 - val_accuracy: 0.8415 - val_precision: 0.8427 - val_recall: 0.8400
# Epoch 7/25
# 11/11 [==============================] - 74s 7s/step - loss: 1.1706 - accuracy: 0.8235 - precision: 0.8247 - recall: 0.8220 - val_loss: 0.5198 - val_accuracy: 0.8404 - val_precision: 0.8415 - val_recall: 0.8398
# Epoch 8/25
# 11/11 [==============================] - 79s 7s/step - loss: 0.9972 - accuracy: 0.8383 - precision: 0.8395 - recall: 0.8372 - val_loss: 0.3642 - val_accuracy: 0.8673 - val_precision: 0.8694 - val_recall: 0.8655
# Epoch 9/25
# 11/11 [==============================] - 80s 7s/step - loss: 0.8940 - accuracy: 0.8495 - precision: 0.8513 - recall: 0.8479 - val_loss: 0.3715 - val_accuracy: 0.8554 - val_precision: 0.8575 - val_recall: 0.8532
# Epoch 10/25
# 11/11 [==============================] - 80s 7s/step - loss: 0.9004 - accuracy: 0.8380 - precision: 0.8405 - recall: 0.8354 - val_loss: 0.3315 - val_accuracy: 0.8548 - val_precision: 0.8581 - val_recall: 0.8511
# Epoch 11/25
# 11/11 [==============================] - 78s 7s/step - loss: 0.8284 - accuracy: 0.8414 - precision: 0.8442 - recall: 0.8385 - val_loss: 0.3833 - val_accuracy: 0.8485 - val_precision: 0.8504 - val_recall: 0.8465
# Epoch 12/25
# 11/11 [==============================] - 79s 7s/step - loss: 0.8027 - accuracy: 0.8442 - precision: 0.8464 - recall: 0.8419 - val_loss: 0.3215 - val_accuracy: 0.8678 - val_precision: 0.8698 - val_recall: 0.8659
# Epoch 13/25
# 11/11 [==============================] - 79s 7s/step - loss: 0.7736 - accuracy: 0.8571 - precision: 0.8593 - recall: 0.8548 - val_loss: 0.3876 - val_accuracy: 0.8491 - val_precision: 0.8511 - val_recall: 0.8472
# Epoch 14/25
# 11/11 [==============================] - 79s 7s/step - loss: 0.7751 - accuracy: 0.8454 - precision: 0.8477 - recall: 0.8433 - val_loss: 0.2683 - val_accuracy: 0.8871 - val_precision: 0.8904 - val_recall: 0.8844
# Epoch 15/25
# 11/11 [==============================] - 76s 7s/step - loss: 0.7792 - accuracy: 0.8495 - precision: 0.8521 - recall: 0.8471 - val_loss: 0.3029 - val_accuracy: 0.8781 - val_precision: 0.8806 - val_recall: 0.8759
# Epoch 16/25
# 11/11 [==============================] - 80s 7s/step - loss: 0.7784 - accuracy: 0.8504 - precision: 0.8529 - recall: 0.8481 - val_loss: 0.3141 - val_accuracy: 0.8634 - val_precision: 0.8656 - val_recall: 0.8612
# Epoch 17/25
# 11/11 [==============================] - 84s 8s/step - loss: 0.7702 - accuracy: 0.8501 - precision: 0.8524 - recall: 0.8478 - val_loss: 0.4217 - val_accuracy: 0.8374 - val_precision: 0.8387 - val_recall: 0.8361
# Epoch 18/25
# 11/11 [==============================] - 79s 7s/step - loss: 0.7381 - accuracy: 0.8498 - precision: 0.8516 - recall: 0.8478 - val_loss: 0.2495 - val_accuracy: 0.8988 - val_precision: 0.9015 - val_recall: 0.8961
# Epoch 19/25
# 11/11 [==============================] - 78s 7s/step - loss: 0.7402 - accuracy: 0.8656 - precision: 0.8677 - recall: 0.8634 - val_loss: 0.3127 - val_accuracy: 0.8662 - val_precision: 0.8676 - val_recall: 0.8647
# Epoch 20/25
# 11/11 [==============================] - 71s 6s/step - loss: 0.6877 - accuracy: 0.8599 - precision: 0.8615 - recall: 0.8582 - val_loss: 0.2909 - val_accuracy: 0.8770 - val_precision: 0.8786 - val_recall: 0.8752
# Epoch 21/25
# 11/11 [==============================] - 71s 6s/step - loss: 0.6764 - accuracy: 0.8667 - precision: 0.8682 - recall: 0.8651 - val_loss: 0.3567 - val_accuracy: 0.8504 - val_precision: 0.8516 - val_recall: 0.8490
# Epoch 22/25
# 11/11 [==============================] - 86s 8s/step - loss: 0.6349 - accuracy: 0.8699 - precision: 0.8715 - recall: 0.8683 - val_loss: 0.2889 - val_accuracy: 0.8852 - val_precision: 0.8863 - val_recall: 0.8839
# Epoch 23/25
# 11/11 [==============================] - 74s 7s/step - loss: 0.6540 - accuracy: 0.8702 - precision: 0.8717 - recall: 0.8686 - val_loss: 0.3385 - val_accuracy: 0.8668 - val_precision: 0.8677 - val_recall: 0.8657
# Epoch 24/25
# 11/11 [==============================] - 76s 7s/step - loss: 0.6738 - accuracy: 0.8648 - precision: 0.8659 - recall: 0.8635 - val_loss: 0.2335 - val_accuracy: 0.9144 - val_precision: 0.9156 - val_recall: 0.9132
# Epoch 25/25
# 11/11 [==============================] - 72s 7s/step - loss: 0.6941 - accuracy: 0.8751 - precision: 0.8763 - recall: 0.8737 - val_loss: 0.3962 - val_accuracy: 0.8632 - val_precision: 0.8641 - val_recall: 0.8623

# %%
"""
Plot the loss and validation accuracy at each epoch

"""
loss = history.history["loss"]
val_loss = history.history["val_loss"]

acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

epochs = range(1, len(loss) + 1)

fig, axes = plt.subplots(1, 2)
axes[0].plot(epochs, loss, "y", label="Training")
axes[0].plot(epochs, val_loss, "r", label="Validation")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Loss")

axes[1].plot(epochs, acc, "y", label="Training")
axes[1].plot(epochs, val_acc, "r", label="Validation")
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("Accuracy")
axes[0].legend()

fig.savefig("training.png")

# %%
"""
Calculate intersection over union for each class using the test set

"""
from keras.metrics import MeanIoU

X_test = processing.imgs2array(np.array(test_images))
y_test = processing.masks2matrix(np.array(test_masks), n_classes)

IOU_keras = MeanIoU(num_classes=n_classes)
IOU_keras.update_state(y_test[:, :, :, 0], model.predict(X_test).argmax(axis=3))


def calculate_iou(values, class_idx):
    iou = values[class_idx, class_idx] / (
        values[class_idx, :].sum()
        + values[:, class_idx].sum()
        - values[class_idx, class_idx]
    )
    return iou


values = np.array(IOU_keras.get_weights()).reshape(n_classes, n_classes)

for i in range(n_classes):
    class_iou = calculate_iou(values, i)
    print(f"IoU for class {i} is: ", class_iou)
# Out:
# 4/4 [==============================] - 5s 938ms/step
# IoU for class 0 is:  0.00014941466
# IoU for class 1 is:  0.05001089
# IoU for class 2 is:  0.0

# %%
""" Show the prediction for some of the training images """
from matplotlib.colors import ListedColormap


def preprocess_image(image):
    # Add batch axis
    return image[np.newaxis, ...]


# Choose some images and masks at random
fig, axes = plt.subplots(3, 4, figsize=(16, 12))
indices = np.random.randint(0, len(X_train), size=len(axes.ravel()))


def plot_predictions(axes, indices, images):
    cmap = ListedColormap(["teal", "magenta", "gold"])

    for index, axis in zip(indices, axes.ravel()):
        prediction = np.argmax(
            model.predict(preprocess_image(images[index]), verbose=0), axis=-1
        ).squeeze()
        axis.set_title(f"Image {index}")
        axis.imshow(images[index], cmap="gray")
        axis.imshow(prediction, cmap=cmap, alpha=0.3)


plot_predictions(axes, indices, X_train)
fig.suptitle("Train Images")
fig.tight_layout()

fig.savefig("training_predictions.png")

# %%
""" Show the prediction for some test images """

# Choose some images at random
indices = np.random.randint(0, len(X_test), size=len(axes.ravel()))

fig, axes = plt.subplots(3, 4, figsize=(16, 12))
plot_predictions(axes, indices, X_test)

fig.suptitle("Test Images")
fig.tight_layout()
fig.savefig("test_predictions.png")

# %%
"""
Plot the testing masks and predictions for a single image

"""
fig, axes = plt.subplots(3, 4, figsize=(16, 12))

for index, axis in zip(indices, axes.ravel()):
    axis.set_title(f"Image {index}")
    prediction = np.argmax(
        model.predict(preprocess_image(test_images[index]), verbose=0), axis=-1
    ).squeeze()
    axis.imshow(test_masks[index], cmap=ListedColormap(["white", "green", "red"]), alpha=0.3)
    mappable = axis.imshow(prediction, cmap=ListedColormap(["white", "green", "red"]), alpha=0.3)


fig.suptitle("Test Images")
fig.tight_layout()

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(mappable, cax=cbar_ax)
